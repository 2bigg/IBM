# %% [markdown]
# My jupyter notebook on IBM Watson studio

# %% [markdown]
# # Abubaker abdalgadir

# %% [markdown]
# im interested in data science becasue of im dealing with data

# %% [markdown]
# type "Hello world"

# %%
#type [Hello_world]

# %% [markdown]
# one
# tow
# three
# four
# | Markdwon| less| pretty|
# |--------|----|------|
# | still| render| nicely|
# | 1| 2| 3|
# www.IBM.com
